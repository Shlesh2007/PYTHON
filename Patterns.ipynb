# %%
a=5
for i in range(10):
    a+=1
    if i%2==0:
        a+=1
        continue
    else:
        print(3)
    break
print(a)
# Out:
# 3
# 8

# %%
#for-else
#else execute after complete execution of for loop
a=1
for i in range(10):
    if i%3==0:
        continue
else
# Out:
#   File "<ipython-input-4-1e76dacbc3b5>", line 7
#     else
#         ^
# SyntaxError: invalid syntax

# %%
#max,min,2nd max,avg,2nd min
max1=0
max2=0
min2=0
min2=0
summ=0
c=0
while True:
    n=input("Enter Marks of the Student:")
    if n=='Done':
        break
    n=int(n)    
    if n<0 or n>100:
        print("Invalid Marks Try Again!!")
    else :
        summ+=n
        if c==0:
            max1=n
            min1=n
            c+=1
        else:
            c+=1
            if n>max1 or n<max2:
                max2=max1
                max1=n
                
            elif n<min1: 
                print(min1,min2)
                min2=min1
                min1=n
            elif n>min1 and n<min2:
                min2=n
avg=summ/c                
print(f"Sum: {summ}")
print(f"First Max: {max1}")
print(f"Second Max: {max2}")
print(f"First Min: {min1}")
print(f"Second Min:{min2}")
print(f"Avrage: {avg}")
# Out:
# Enter Marks of the Student:20
# Enter Marks of the Student:30
# Enter Marks of the Student:40
# Enter Marks of the Student:50
# Enter Marks of the Student:60
# Enter Marks of the Student:Done
# Sum: 200
# First Max: 60
# Second Max: 50
# First Min: 20
# Second Min:0
# Avrage: 40.0

# %%
n=int(input("Enter Number="))
for r in range(1,n+1):
    for c in range (1,n+1):
        print('*',end=" ")
    print()
# Out:
# Enter Number=5
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
n=int(input("Enter R="))
for i in range(1,n+1):
    for j in range (1,i+1):
        print('*',end=" ")
    print()
# Out:
# Enter R=5
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n=int(input("Enter R="))
for i in range(1,n+1):
    for j in range (n+1,i,-1):
        print("*",end=" ")
    print()
# Out:
# Enter R=5
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
n=int(input("Enter R="))
for i in range(1,n+1):
    for j in range (n+1,i,-1):
        print(' ',end=" ")
    for k in range (1,i+1):
        print('*',end=" ")
    print()
# Out:
# Enter R=5
#           *
#         * *
#       * * *
#     * * * *
#   * * * * *

# %%
n=int(input("Enter R="))
for i in range(1,n+1):
    for j in range (1,i+1):
        print(' ',end=" ")
    for k in range (n+1,i,-1):
        print('*',end=" ")
    print()
# Out:
# Enter R=5
#   * * * * *
#     * * * *
#       * * *
#         * *
#           *

# %%
n=int(input("Enter R="))
for i in range(1,n+1):
    for j in range (n+1,i,-1):
        print(" ",end=" ")
    for k in range(1,i+1):
        print("*",end=" ")
    for g in range (2,i+1):
        print("*",end=" ")
    print()
for i1 in range(1,n+1):
    for j1 in range(1,i+1):
        print(' ',end=" ")
    for k1 in range (n,i,-1):
        print("*",end=" ")
    for l in range (n,i+1,-1):
        print("*",end=" ")
    print()
# Out:
# Enter R=5
#           *
#         * * *
#       * * * * *
#     * * * * * * *
#   * * * * * * * * *
