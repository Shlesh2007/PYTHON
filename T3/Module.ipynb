# %%
# views.py ,models.py, urls.py, sa lite-3:-django

# %%
#Module
from datetime import date,time,datetime

# %%
date.today()
x=date(2025,11,2)
print(x)
# Out:
# 2025-11-02

# %%
time(8,10,3)
# Out:
# datetime.datetime(2025, 10, 14, 3, 27, 31, 619198)

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 10, 14, 3, 28, 14, 323094)

# %%
import os

# %%
pwd ## method of jupyter
# Out:
# 'D:\\Shlesh-Python'

# %%
os.getcwd() ##current/present working directory
# Out:
# 'D:\\Shlesh-Python'

# %%
os.chdir('..')##change directory to parent

# %%
os.getcwd()
# Out:
# 'D:\\'

# %%
os.mkdir('D:/VHA')##NEW DIRECTORY inside D:

# %%
os.mkdir('D:/VHA/VHA10') ## New directory inside VHA Directory

# %%
os.chdir('D:/VHA')

# %%
os.getcwd()
# Out:
# 'D:\\VHA'

# %%
os.listdir('C:') ##subdirectory-files
# Out:
# ['!qhlogs.doc',
#  '$Recycle.Bin',
#  '$WinREAgent',
#  'cfrbackup-WZITMJTO',
#  'Config.Msi',
#  'DEMO',
#  'Documents and Settings',
#  'DumpStack.log',
#  'DumpStack.log.tmp',
#  'hiberfil.sys',
#  'inetpub',
#  'Insight Files',
#  'Intel',
#  'logs',
#  'msdia80.dll',
#  'MSOCache',
#  'oraclexe',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Recovery',
#  'RESULT',
#  'swapfile.sys',
#  'System Volume Information',
#  'TurboC++',
#  'Users',
#  'Windows',
#  'xampp']

# %%
os.listdir('D:')
# Out:
# ['VHA10']

# %%
os.getcwd()
# Out:
# 'D:\\VHA'

# %%
f1=open('File1.txt','w')
f2=open('File2.txt','w')
f1.write('Hello')
f2.write('Welcome')
f1.close()
f2.close()

# %%
os.listdir('d:/VHA')
# Out:
# ['File1.txt', 'File2.txt', 'VHA10']

# %%
## TO REMOVE
os.remove('D:/VHA/File1.txt')

# %%
os.rmdir('d:/vha')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-42-57e6edd3f9f8> in <module>
# ----> 1 os.rmdir('d:/vha')
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:/vha'

# %%
os.rmdir('d:/vha/vha10')

# %%
os.remove('d:/vha/File2.txt')

# %%
os.chdir('..')
os.getcwd()
# Out:
# 'D:\\'

# %%
import os
os.rmdir('D:/VHA')

# %%
import Calc
print(Calc.x)
print(Calc.sumation(5,7))
# Out:
# 10
# 12

# %%
import Calc as c
c.sumation(3,5)
# Out:
# 8

# %%
from Calc import sumation
sumation(3,5)
# Out:
# 8

# %%
deletion(3,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-337d86b25e3f> in <module>
# ----> 1 deletion(3,5)
#
# NameError: name 'deletion' is not defined

# %%
from Calc import *
print(x)
print(sumation(3,5))
print(deletion(6,4))
# Out:
# 10
# 8
# 2

# %%
from A1 import *

# %%
print(count('is is is','is'))
# Out:
# 3
