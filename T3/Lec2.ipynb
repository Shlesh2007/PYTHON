# %%
try:
    f=open('VHA.txt')
    print('Hi')
except:
    print("File not Available")
# Out:
# File not Available

# %%
try:
    f=open('Shlesh.txt','w')
    print(Hi)
except Exception as e:
    print(e.with_traceback)
    f.close()
# Out:
# <built-in method with_traceback of NameError object at 0x000001A546FBC1D0>

# %%
try:
    f=open('S1.txt','w')
    d={'1':4}
    print('hi')
    d['3']
except FileNotFoundError:
    print('File Not Found')
except NameError:
    print('Name Error')
except KeyError:
    print('Key Error')
# Out:
# hi
# Key Error

# %%
try:
    f=open('S1.txt','w')
    d={'1':4}
    print('hi')
    d['3']
except FileNotFoundError:
    print('File Not Found')
except NameError:
    print('Name Error')
except KeyError:
    print('Key Error')
print('B1 IS BEST')
# Out:
# hi
# Key Error
# B1 IS BEST

# %%
try:
    f=open('S1.txt','w')
    d={'1':4}
    print('hi')
    d['3']
except FileNotFoundError:
    print('File Not Found')
except NameError:
    print('Name Error')
except KeyError:
    print('Key Error')
else:
    print('B1 IS BEST')
# Out:
# hi
# Key Error

# %%
try:
    f=open('VHA.txt')
except:
    print('Sorry')
else:
    print(f.read())
finally:
    print('Everytime i will disturb you ')
# Out:
# Everytime i will disturb you

# %%
def f():
    try:
        print(1)
    finally:
        print(2)
print(f())
# Out:
# 1
# 2
# None

# %%
def f():
    try:
        return 1
    finally:
        return 2
print(f())
# Out:
# 2

# %%
def f():
    try:
        print('VHA')
        return 1
    finally:
        print(10)
        return 2
print(f())
# Out:
# VHA
# 10
# 2

# %%
##flow try-except-else-finally
##try-finally
##try-except-else

# %%
##custome error
raise NameError('variable not defined properly')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-45bc7f33c839> in <module>
#       1 ##custome error
# ----> 2 raise NameError('variable not defined properly')
#
# NameError: variable not defined properly

# %%
name=input("Enter Name: ")
try:
    value=int(input("Enter Value: "))
    if value!=10:
        raise Exception('Only 10')
    print(value)
except Exception as e:
    print(e)
# Out:
# Enter Name: Shlesh
# Enter Value: 55
# Only 10

# %%
class Vishal(Exception):
    def __init__(self,message):
        pass

# %%
try:
    wamt=int(input("Enter Withrawal Amount: "))
    amt=int(input('Enter Balance: '))
    if wamt<0:
        raise Exception('The Withdrawal Amount could not be negative')
    elif wamt>amt:
        raise Vishal("The Witdrawal Amount is more then Balance amount")
except Exception as e:
    print(e.with_traceback)
else:
    print('Final Balance: ',(amt-wamt))
finally:
    print('Welcome')
# Out:
# Enter Withrawal Amount: 500
# Enter Balance: 100
# <built-in method with_traceback of Vishal object at 0x000001A5495AE4C0>
# Welcome

# %%
L=[1,2]
print(type(L))
print(L.upper())
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-e83a5cf1770a> in <module>
#       1 L=[1,2]
#       2 print(type(L))
# ----> 3 print(L.upper())
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
class Atm:
    def __init__(self):
        self.pin=" "
        self.balance=50000
        print('Automatic')
#         self.menu()
#     def menu(self):
#         choice=input("1. Masala Cheese Waffle Dosa \n2. Panner Cheese Dosa\n")
obj1=Atm()
print(obj1.balance)
print(obj1.pin)
# Out:
# Automatic
# 50000

# %%
class Atm:
    def __init__(self):
        self.pin=" "
        self.balance=50000
        print('Automatic')
        print(id(self))
    def menu():
        choice=input("1. Masala Cheese Waffle Dosa \n2. Panner Cheese Dosa\n")

o1=Atm()
print(id(o1))
o1.menu()#TypeError: menu() takes 0 positional arguments but 1 was given
o2=Atm()
print(id(o2))
# Out:
# Automatic
# 2060996025360
# 2060996025360
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-72164fcc46fc> in <module>
#      10 o1=Atm()
#      11 print(id(o1))
# ---> 12 o1.menu()
#      13 o2=Atm()
#      14 print(id(o2))
#
# TypeError: menu() takes 0 positional arguments but 1 was given

# %%
class Atm:
    def __init__(self,pin,balance):
        self.pin=pin
        self.balance=balance
        print('Automatic')
        print(id(self),pin,balance)
#     def menu(self):
#         choice=input("1. Masala Cheese Waffle Dosa \n2. Panner Cheese Dosa\n")

o1=Atm("44",65000)
print(id(o1))
# o1.menu()#TypeError: menu() takes 0 positional arguments but 1 was given
o2=Atm("23",25000)
print(id(o2))
print(o1.pin)
print(o1.balance)
print(id(o1.balance))
o1.balance=5000
print(o1.balance)
print(id(o1))
print(id(o1.balance))
# Out:
# Automatic
# 2524843216464 44 65000
# 2524843216464
# Automatic
# 2524843378480 23 25000
# 2524843378480
# 44
# 65000
# 2524843205520
# 5000
# 2524843216464
# 2524843205648

# %%
class A:
    age=19
    def __init__(self,name,age):
        self.name=name
        print(self.name)
    def display(self):
        print(self.name,self.age)
o=A('Shlesh',18)
o.display()
# Out:
# Shlesh
# Shlesh 19
