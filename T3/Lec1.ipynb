# %%
# SyntaxError
# NameError
# ValueError
# IndexError 
# FileNotFoundError  
# ZeroDivisionError  
# ModuleNotFoundError
##first letter capital so it's pascal
a=10
print 'Hello'
# Out:
#   File "<ipython-input-3-d8e3b2eeb02b>", line 2
#     print 'Hello'
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('Hello')?

# %%
''B1 IS BEST'
# Out:
#   File "<ipython-input-4-ef56423be5bc>", line 1
#     ''B1 IS BEST
#       ^
# SyntaxError: invalid syntax

# %%
iff 3>4:
    print('helll')
# Out:
#   File "<ipython-input-7-e1185144933b>", line 1
#     iff 3>4:
#         ^
# SyntaxError: invalid syntax

# %%
for i in range(10):
# Out:
#   File "<ipython-input-8-e61162350cc4>", line 1
#     for i in range(10):
#                        ^
# SyntaxError: unexpected EOF while parsing

# %%
class Vishal:
# Out:
#   File "<ipython-input-9-2f13df65d1c8>", line 1
#     class Vishal:
#                  ^
# SyntaxError: unexpected EOF while parsing

# %%
def f():
# Out:
#   File "<ipython-input-10-2ba2580b0af7>", line 1
#     def f():
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
s j j
# Out:
#   File "<ipython-input-11-da72e847f1bd>", line 1
#     s j j
#       ^
# SyntaxError: invalid syntax

# %%
print('Hi
# Out:
#   File "<ipython-input-12-e34732188fe3>", line 1
#     print('Hi
#              ^
# SyntaxError: EOL while scanning string literal

# %%
L=[3,5
# Out:
#   File "<ipython-input-13-d49647798a0e>", line 1
#     L=[3,5
#           ^
# SyntaxError: unexpected EOF while parsing

# %%
d={'A':3
# Out:
#   File "<ipython-input-14-a1486d207723>", line 1
#     d={'A':3
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-939330b76721> in <module>
# ----> 1 print(A)
#
# NameError: name 'A' is not defined

# %%
print(dfdfd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e356079a17fc> in <module>
# ----> 1 print(dfdfd)
#
# NameError: name 'dfdfd' is not defined

# %%
print(a='b')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-1c881bdbd12e> in <module>
# ----> 1 print(a='b')
#
# TypeError: 'a' is an invalid keyword argument for print()

# %%
3+'3'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-5e829c909994> in <module>
# ----> 1 3+'3'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
int('Shlesh')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-19653a68bafa> in <module>
# ----> 1 int('bha')
#
# ValueError: invalid literal for int() with base 10: 'bha'

# %%
L=[1]
print(L[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-139d334a2c66> in <module>
#       1 L=[1]
# ----> 2 print(L[2])
#
# IndexError: list index out of range

# %%
L=[1]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-229d8cd87a90> in <module>
#       1 L=[1]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
d={'a':1}
print(d[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-e3af549018d0> in <module>
#       1 d={'a':1}
# ----> 2 print(d[2])
#
# KeyError: 2

# %%
f=open('Shlesh.txt','r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-5f135334e234> in <module>
# ----> 1 f=open('Shlesh.txt','r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Shlesh.txt'

# %%
import vha
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-799856beee65> in <module>
# ----> 1 import vha
#
# ModuleNotFoundError: No module named 'vha'

# %%
3/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-29-f6cc6d14333b> in <module>
# ----> 1 3/0
#
# ZeroDivisionError: division by zero

# %%
f=open('untitled.txt','r')
s=input("Do You Really Want to read thi file? (Yes/No):")
while s=='Yes':
    for i in range(5):
        print(f.readline())
    s=input("Do You Want to read 5 more Lines? (Yes/No):")
    if s=='Yes':
        print("Okay 😘")
        continue
    else:
        print("Okay then Get Out From Here!!!🙄")
        break
# Out:
# Do You Really Want to read thi file? (Yes/No):Yes
# 11/09/2009 AlcornSt. 60 OhioSt. 100
#
# 11/09/2009 FloridaInternational 72 NorthCarolina 88
#
# 11/09/2009 Albany 43 Syracuse 75
#
# 11/09/2009 MurraySt. 70 California 75
#
# 11/11/2009 RobertMorris 60 Syracuse 100
#
# Do You Want to read 5 more Lines? (Yes/No):Yes
# Okay 😘
# 11/11/2009 NorthCarolinaCentral 42 NorthCarolina 89
#
# 11/11/2009 Detroit 61 California 95
#
# 11/12/2009 JamesMadison 44 OhioSt. 72
#
# 11/12/2009 GeorgiaSt. 53 NorthCarolinaSt. 69
#
# 11/13/2009 WesternSt. 54 AirForce 65
#
# Do You Want to read 5 more Lines? (Yes/No):No
# Okay then Get Out From Here!!!🙄

# %%
try:
    print(1)
finally:
    print(2)
# Out:
# 1
# 2

# %%
def f():
    try:
        return 1
    finally:
        return 2
print(f())
# Out:
# 2
