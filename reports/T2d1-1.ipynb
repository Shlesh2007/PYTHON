# %%
s='B1 is Best'#0-B 9-t,to access 0 location it first goes to id of that string and then go to that string from that id
print(type(s))#-9:B -1:t
print(id(s))
print(id(s[3]))
print(id(s[0]))
# Out:
# <class 'str'>
# 2330247558000
# 2330171689136
# 2330177106608

# %%
print(s[-7])
# Out:
# i

# %%
# to access sub string 
s='Welcome'
#s[start(0):end(len(s))(excluding):step(1)]() denotes the default values 
s[0:7:1]
s[0:7]
s[:7]
s[0:]
s[1:4:1]


s='B1 is Best'
# Out:
# 'elc'

# %%
s='B1 is Best'
s[::2]
# Out:
# 'B sBs'

# %%
s[-1:-6:-1]
# Out:
# ']hsel'

# %%
s=input("Enter Word: ")
if s==s[::-1]:
    print("Yeah It's Palindrome Number")
else:
    print("Yup It's not a plaindrome  Number")
# Out:
# Enter Word: Shlesh]
# Yup It's not a plaindrome  Number

# %%
s='B1 is Best'
s[-1:-5:-1]
# Out:
# 'tseB'

# %%
s='VHA-10'
s[3]=':'#String cannot be change or modified (inmutable)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-4638ab1180e2> in <module>
#       1 s='VHA-10'
# ----> 2 s[3]=':'
#
# TypeError: 'str' object does not support item assignment

# %%
s='VHA-10'
print(id(s))
print(s)
s=s[0:3]+':'+s[4:]
print(id(s))
print(s)
# Out:
# 2330247680880
# VHA-10
# 2330247683824
# VHA:10

# %%
del s
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-5477e9d4b00d> in <module>
#       1 del s
# ----> 2 print(s)
#
# NameError: name 's' is not defined

# %%
s='Hello'
s[-11]
s[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-f86eeabd44d3> in <module>
#       1 s='Hello'
# ----> 2 s[-11]
#       3 s[7]
#
# IndexError: string index out of range

# %%
"" and False
"False" and False
"" or True
'v' in 'vishal'
'v' not in 'vishal'
#'1' in 123#error
# Out:
# False

# %%
s='Welcome'
# for i in s:
#     print(i,end="")
count=0
for i in s:
    print(f"{count} >",i)
    count=count+1
print('---------------')
for i in range(0,len(s)):
    print(i,'>',s[i])
print('---------------')
for index,char in enumerate(s):
    print(index,'>',char)
enumerate(s)
# Out:
# 0 > W
# 1 > e
# 2 > l
# 3 > c
# 4 > o
# 5 > m
# 6 > e
# ---------------
# 0 > W
# 1 > e
# 2 > l
# 3 > c
# 4 > o
# 5 > m
# 6 > e
# ---------------
# 0 > W
# 1 > e
# 2 > l
# 3 > c
# 4 > o
# 5 > m
# 6 > e

# %%
#not correct
s1=input("Enter first Word: ")
s2=input("Enter Second Word: ")
flag=False
for i in s1:
    for j in s2:
        if i==j:
            flag=True
        else:
            flag=False
            break
else:
    for i1 in s2:
        for j1 in s1:
            if i1==j1:
                flag=True
            else:
                flag=False
                break
if flag==True:
    print("It's Balanced String")
else:
    print("It's not a Balanced String")
# Out:
# Enter first Word: ass
# Enter Second Word: ssa
# It's not a Balanced String

# %%
s="01234567890123456789"
for i,c in enumerate(s):
        print(c,end="")
        if i%5==0 and i!=0:
            ans=input("Yes/No: ")
            if ans=="Yes":
                pass
            else:
                break
# Out:
# 012345Yes/No: Yes
# 67890Yes/No: Yes
# 12345Yes/No: Yes
# 6789

# %%
s='welcome'
print(len(s))#7
print(max(s))#w(by ascii Value)
print(min(s))#c(by ascii Value)
print(sorted(s))#['c', 'e', 'e', 'l', 'm', 'o', 'w']
print(sorted(s,reverse=True))#['w', 'o', 'm', 'l', 'e', 'e', 'c']
# Out:
# 7
# w
# c
# ['c', 'e', 'e', 'l', 'm', 'o', 'w']
# ['w', 'o', 'm', 'l', 'e', 'e', 'c']
