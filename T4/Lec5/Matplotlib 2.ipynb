# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,99]
y=[10,2,3,5,78]
plt.hist(x,alpha=0.5)
plt.show()

# %%
plt.fill_between(x,y)
z=[1,2,3,5,7]
plt.fill_between(x,z,alpha=0.6)
plt.show()

# %%
# advanced version
plt.stackplot(x,y)
plt.show()
