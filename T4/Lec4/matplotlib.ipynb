# %%
import matplotlib.pyplot as plt

# %%
x=[1,5]
y=[10,20]
plt.plot(x,y,"o")
plt.show()

# %%
import numpy as np
x1=np.array([1,6,9,2,5,10])
y2=np.array([10,20,5,4,2,20])
plt.plot(x1,y2,"o")
plt.show()

# %%
x=[1,6,9,2,5,10]
y=[10,20,5,4,2,20]
plt.plot(x,y,marker="*",ms=20,mec="red",mfc="yellow")
plt.show()

# %%
x=[1,6,9,2,5,10]
y=[10,20,5,4,2,20]
f1={"family":"serif","color":"blue","size":30}

f={"family":"serif","color":"red","size":20}
plt.subplot(3,3,1)
plt.plot(x,y,marker="*",ms=20,mec="red",mfc="yellow",color="red",linewidth=5,linestyle="-.")
plt.xlabel("no of match",fontdict=f1)
plt.ylabel("runs")
plt.title("ind vs aus",fontdict=f)

x=[1,6,9,2,5,10]
y=[10,20,5,4,2,20]
plt.subplot(3,3,9)
plt.plot(x,y,marker="*",ms=20,mec="red",mfc="yellow")
plt.show()

# %%
a=[1,6,9,2,5,10]
x=[11,61,19,12,15,10]
y=[10,20,5,4,2,20]
plt.plot(a)
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x=[1,6,9,2,5,10]
y=[10,20,5,4,2,20]
plt.plot(x,y,marker="*",ms=20,mec="red",mfc="yellow")
plt.grid(color="green",linewidth=5,axis="x")
plt.show()

# %%
x=[1,6,9,2,5,10]
y=[10,20,5,4,2,20]
f1={"family":"serif","color":"blue","size":30}


plt.plot(x,y,marker="*",ms=20,mec="red",mfc="yellow",color="red",linewidth=5,linestyle="-.")
plt.xlabel("no of match",fontdict=f1)
plt.ylabel("runs")
plt.title("ind vs aus",fontdict=f,loc="left")
plt.show()

# %% [markdown]
# # scatter plot

# %%
x=[1,6,9,2,5,10]
y=[10,20,5,4,2,20]
plt.scatter(x,y)
plt.show()

# %%
x=["T1","T2","T3","T4"]
m=[25,20,8,30]
z=[25,10,20,40]
c1=["green","blue","black","yellow"]
s1=[200,300,500,1000]
plt.scatter(x,m,c=c1,s=s1,alpha=0.5)
plt.scatter(x,z,c=c1,alpha=0.9)
""
plt.show()

# %%
x=["T1","T2","T3","T4"]
m=[25,20,8,30]
plt.barh(x,m,color="red")
plt.show()

# %%
x=["T1","T2","T3","T4"]
m=[25,20,8,30]
plt.bar(x,m,color="red")
plt.show()

# %%
m=[25,20,8,30]
x=["T1","T2","T3","T4"]
e=[0.5,0,0.2,0]
plt.pie(m,labels=x,startangle=90,autopct="%1.f")
plt.legend(title="marks")
plt.show()
